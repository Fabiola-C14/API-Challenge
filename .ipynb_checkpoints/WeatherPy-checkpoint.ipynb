# %% [markdown]
# # WeatherPy

# %%
#Import pandas, requests, pprint, citipy, config key

import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
import time
import scipy.stats as st
import json
import pprint
from citipy import citipy
from datetime import datetime
from config import api_key

# Create outbound file (CSV)
output_data_file = "data_city_list.csv"

# %%
# Set coordinates
lat_coord = (-90, 90)
lng_coord = (-180, 180)

#  Create list for longitude, latitude, city and country
lat_lng = []
city_list = []
country_list = []

# Create citites with random latitudes and longitudes
lat = np.random.uniform(low=-90.000, high=90.000, size=1500)
lng = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lng = zip(lat, lng)

# Identify unique cities
for unique_lat_lng in lat_lng:
    city = citipy.nearest_city(unique_lat_lng[0], unique_lat_lng[1]).city_name
    
    
    # Add unique cities to the list
    if city not in city_list:
        city_list.append(city)

len(city_list)
# Out:
# 605

# %%
# Set weather url
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# %%
# Create list to add the variables
city_id= []
city_name = []
country = []
latitude = []
longitude = []
date=[]
humidity = []
temperature = []
wind_speed = []
cloudiness = []
count=0

#Extract weather for various cities from the city list
for city in city_list:
    query_url = f"{url}appid={api_key}&q={city}&units={units}"
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()
    try:
        cityid=weather_json["id"]
        cityname=weather_json["name"]
        countrycode=weather_json["sys"]["country"]
        lat=weather_json["coord"]["lat"]
        long=weather_json["coord"]["lon"]
        weatherdate = (datetime.fromtimestamp(response['dt'])).strftime('%m/%d/%y')
        hum=weather_json["main"]["humidity"]
        temp=weather_json["main"]["temp"]
        windspeed=weather_json["wind"]["speed"]
        cloud=weather_json["clouds"]["all"]
        
        city_id.append(int(cityid))
        city_name.append(cityname)
        country.append(countrycode)
        latitude.append(lat)
        longitude.append(long)
        date.append(weatherdate)
        humidity.append(hum)
        temperature.append(temp)
        wind_speed.append(windspeed)
        cloudiness.append(cloud)
        
        #Set a count of records found/not found
        count=count+1
        
        print(f"Record {count},city name:{cityname} with city ID: {cityid} was found")
    except:
        print(f"{city}, was not found")
        pass
        
print("Data Extract Completed")
# Out:
# Record 1,city name:Busselton with city ID: 2075265 was found
# Record 2,city name:Saint-Philippe with city ID: 935215 was found
# Record 3,city name:Ukiah with city ID: 5404476 was found
# Record 4,city name:Chumikan with city ID: 2025256 was found
# Record 5,city name:Bredasdorp with city ID: 1015776 was found
# Record 6,city name:Qaanaaq with city ID: 3831208 was found
# Record 7,city name:Mahébourg with city ID: 934322 was found
# Record 8,city name:Santiago with city ID: 3871336 was found
# Record 9,city name:Auxerre with city ID: 3035843 was found
# Record 10,city name:Ushuaia with city ID: 3833367 was found
# Record 11,city name:Hermanus with city ID: 3366880 was found
# Record 12,city name:Punta Arenas with city ID: 3874787 was found
# Record 13,city name:Avarua with city ID: 4035715 was found
# Record 14,city name:Kruisfontein with city ID: 986717 was found
# Record 15,city name:Warri with city ID: 2319133 was found
# Record 16,city name:San Cristobal with city ID: 3628473 was found
# Record 17,city name:Tuatapere with city ID: 2180815 was found
# Record 18,city name:Mataura with city ID: 6201424 was found
# Record 19,city name:Ciudad Bolivar with city ID: 3645532 was found
# belushya guba, was not found
# illoqqortoormiut, was not found
# Record 20,city name:Sitka with city ID: 5557293 was found
# Record 21,city name:Port Alfred with city ID: 964432 was found
# Record 22,city name:Urusha with city ID: 2014078 was found
# Record 23,city name:Albany with city ID: 5106841 was found
# Record 24,city name:Píllaro with city ID: 3653159 was found
# Record 25,city name:Provideniya with city ID: 4031574 was found
# Record 26,city name:Kavieng with city ID: 2094342 was found
# tidore, was not found
# Record 27,city name:Korla with city ID: 1529376 was found
# Record 28,city name:Nago with city ID: 1856068 was found
# Record 29,city name:Butaritari with city ID: 2110227 was found
# Record 30,city name:Souillac with city ID: 933995 was found
# Record 31,city name:Fortuna with city ID: 5563839 was found
# Record 32,city name:Yantal' with city ID: 2055868 was found
# Record 33,city name:Senador Guiomard with city ID: 3924752 was found
# Record 34,city name:Atuona with city ID: 4020109 was found
# Record 35,city name:St. George's with city ID: 3579925 was found
# Record 36,city name:Barrow with city ID: 5880054 was found
# Record 37,city name:Sioux Lookout with city ID: 6148373 was found
# Record 38,city name:Geraldton with city ID: 2070998 was found
# Record 39,city name:Severo-Kuril'sk with city ID: 2121385 was found
# Record 40,city name:Jamestown with city ID: 5122534 was found
# Record 41,city name:Hithadhoo with city ID: 1282256 was found
# Record 42,city name:Mayo with city ID: 4362001 was found
# Record 43,city name:Tacoronte with city ID: 2510725 was found
# sataua, was not found
# amderma, was not found
# Record 44,city name:Tasiilaq with city ID: 3424607 was found
# Record 45,city name:Havre-St-Pierre with city ID: 5972291 was found
# Record 46,city name:Saint Paul Harbor with city ID: 5866583 was found
# Record 47,city name:Diré with city ID: 2458624 was found
# Record 48,city name:Rikitea with city ID: 4030556 was found
# Record 49,city name:Ixtapa with city ID: 4004293 was found
# Record 50,city name:Qasigiannguit with city ID: 3420768 was found
# Record 51,city name:Fairbanks with city ID: 5861897 was found
# Record 52,city name:French Harbor with city ID: 3609667 was found
# Record 53,city name:Hilo with city ID: 5855927 was found
# Record 54,city name:George Town with city ID: 1735106 was found
# Record 55,city name:Ilulissat with city ID: 3423146 was found
# wazzan, was not found
# Record 56,city name:Benghazi with city ID: 88319 was found
# Record 57,city name:Hobart with city ID: 2163355 was found
# Record 58,city name:Thompson with city ID: 6165406 was found
# Record 59,city name:Malpe with city ID: 1264037 was found
# Record 60,city name:Dunedin with city ID: 2191562 was found
# Record 61,city name:Bambous Virieux with city ID: 1106677 was found
# Record 62,city name:Andenes with city ID: 3163146 was found
# Record 63,city name:Port Hawkesbury with city ID: 6111867 was found
# Record 64,city name:Nikolskoye with city ID: 546105 was found
# Record 65,city name:East London with city ID: 1006984 was found
# Record 66,city name:Gigmoto with city ID: 1712961 was found
# Record 67,city name:Beisfjord with city ID: 3144987 was found
# Record 68,city name:Bengkulu with city ID: 1649150 was found
# Record 69,city name:Ciudad del Carmen with city ID: 3530599 was found
# Record 70,city name:Chicama with city ID: 3698359 was found
# Record 71,city name:Çorlu with city ID: 748893 was found
# Record 72,city name:Castro with city ID: 3466704 was found
# Record 73,city name:Kaitangata with city ID: 2208248 was found
# Record 74,city name:Chui with city ID: 3443061 was found
# Record 75,city name:Peniche with city ID: 2264923 was found
# Record 76,city name:Ahipara with city ID: 2194098 was found
# Record 77,city name:Esperance with city ID: 2071860 was found
# Record 78,city name:Clyde River with city ID: 5924351 was found
# taolanaro, was not found
# Record 79,city name:Vostok with city ID: 2013279 was found
# Record 80,city name:Esik with city ID: 1523741 was found
# Record 81,city name:Dikson with city ID: 1507390 was found
# Record 82,city name:Bluff with city ID: 2206939 was found
# Record 83,city name:Kloulklubed with city ID: 7671223 was found
# Record 84,city name:Airai with city ID: 1651810 was found
# Record 85,city name:Tefé with city ID: 3661944 was found
# Record 86,city name:Port Elizabeth with city ID: 964420 was found
# attawapiskat, was not found
# Record 87,city name:Sinnamary with city ID: 3380290 was found
# Record 88,city name:Haines Junction with city ID: 5969025 was found
# Record 89,city name:Luganville with city ID: 2136150 was found
# nizhneyansk, was not found
# Record 90,city name:Laguna with city ID: 5364271 was found
# Record 91,city name:Sagarejo with city ID: 612230 was found
# Record 92,city name:Hay River with city ID: 5972762 was found
# wahran, was not found
# Record 93,city name:Kenai with city ID: 5866063 was found
# Record 94,city name:Port Hardy with city ID: 6111862 was found
# Record 95,city name:Yellowknife with city ID: 6185377 was found
# Record 96,city name:Cherskiy with city ID: 2126199 was found
# Record 97,city name:Lüderitz with city ID: 3355672 was found
# samusu, was not found
# Record 98,city name:Coyhaique with city ID: 3894426 was found
# Record 99,city name:Nome with city ID: 5870133 was found
# Record 100,city name:Verkhnyaya Inta with city ID: 1487332 was found
# Record 101,city name:Kirakira with city ID: 2178753 was found
# Record 102,city name:Guangyuan with city ID: 1806466 was found
# Record 103,city name:New Norfolk with city ID: 2155415 was found
# Record 104,city name:San Ignacio with city ID: 3581194 was found
# ngukurr, was not found
# Record 105,city name:Caravelas with city ID: 3466980 was found
# Record 106,city name:Mandalgovi with city ID: 2030065 was found
# Record 107,city name:Upernavik with city ID: 3418910 was found
# meyungs, was not found
# Record 108,city name:San Rafael with city ID: 3836669 was found
# Record 109,city name:Mount Gambier with city ID: 2156643 was found
# Record 110,city name:Vestmannaeyjar with city ID: 3412093 was found
# Record 111,city name:Dārāb with city ID: 137956 was found
# Record 112,city name:Lappeenranta with city ID: 648900 was found
# Record 113,city name:Saskylakh with city ID: 2017155 was found
# Record 114,city name:Bacolod City with city ID: 1729564 was found
# khonuu, was not found
# Record 115,city name:Saint-Pierre with city ID: 935214 was found
# Record 116,city name:Ust-Nera with city ID: 2120048 was found
# Record 117,city name:Havelock with city ID: 4470244 was found
# Record 118,city name:Hamilton with city ID: 4513583 was found
# Record 119,city name:Sept-Îles with city ID: 6144312 was found
# Record 120,city name:Vaini with city ID: 4032243 was found
# Record 121,city name:Riberalta with city ID: 3906466 was found
# Record 122,city name:Lebu with city ID: 3883457 was found
# Record 123,city name:Kumul with city ID: 1529484 was found
# Record 124,city name:Northam with city ID: 2641434 was found
# Record 125,city name:Bakel with city ID: 2252606 was found
# Record 126,city name:Khovd with city ID: 1516048 was found
# Record 127,city name:Kieta with city ID: 2094027 was found
# Record 128,city name:Manyana with city ID: 933416 was found
# Record 129,city name:Jacareacanga with city ID: 3397763 was found
# Record 130,city name:Gambiran with city ID: 8070858 was found
# Record 131,city name:Hambantota with city ID: 1244926 was found
# Record 132,city name:Cidreira with city ID: 3466165 was found
# Record 133,city name:Ponta do Sol with city ID: 2264557 was found
# Record 134,city name:Saldanha with city ID: 3361934 was found
# Record 135,city name:Los Llanos de Aridane with city ID: 2514651 was found
# Record 136,city name:Lompoc with city ID: 5367788 was found
# Record 137,city name:Puerto Ayora with city ID: 3652764 was found
# Record 138,city name:Te Anau with city ID: 2181625 was found
# Record 139,city name:Sakaraha with city ID: 1057095 was found
# Record 140,city name:Glasgow with city ID: 2648579 was found
# Record 141,city name:Cape Town with city ID: 3369157 was found
# Record 142,city name:Alice Springs with city ID: 2077895 was found
# Record 143,city name:Mossamedes with city ID: 3347019 was found
# Record 144,city name:Numāligarh with city ID: 1261142 was found
# Record 145,city name:Ribeira Grande with city ID: 3372707 was found
# Record 146,city name:Khawhai with city ID: 1266821 was found
# Record 147,city name:Samarai with city ID: 2132606 was found
# Record 148,city name:Ternate with city ID: 1624041 was found
# Record 149,city name:Tabuk with city ID: 1684803 was found
# Record 150,city name:Touros with city ID: 3386213 was found
# Record 151,city name:Iqaluit with city ID: 5983720 was found
# Record 152,city name:Atar with city ID: 2381334 was found
# Record 153,city name:Vzmorye with city ID: 6930743 was found
# kamenskoye, was not found
# Record 154,city name:Grenfell with city ID: 2164457 was found
# Record 155,city name:Szendrő with city ID: 715355 was found
# Record 156,city name:Chernyshevskiy with city ID: 2025456 was found
# Record 157,city name:Camacha with city ID: 2270385 was found
# Record 158,city name:Gwembe with city ID: 917011 was found
# Record 159,city name:Srednekolymsk with city ID: 2121025 was found
# Record 160,city name:Mayor Pablo Lagerenza with city ID: 3867427 was found
# Record 161,city name:Punta Alta with city ID: 3839982 was found
# Record 162,city name:Gamba with city ID: 2400547 was found
# Record 163,city name:Pacific Grove with city ID: 5380437 was found
# Record 164,city name:Chunoyar with city ID: 1507638 was found
# Record 165,city name:Damara with city ID: 2387435 was found
# samalaeulu, was not found
# Record 166,city name:Mildura with city ID: 2157698 was found
# Record 167,city name:Klaksvík with city ID: 2618795 was found
# Record 168,city name:Semey with city ID: 1519422 was found
# Record 169,city name:Arraial do Cabo with city ID: 3471451 was found
# Record 170,city name:Quatre Cocos with city ID: 1106643 was found
# Record 171,city name:Vardø with city ID: 777019 was found
# Record 172,city name:Longyearbyen with city ID: 2729907 was found
# mys shmidta, was not found
# Record 173,city name:Atambua with city ID: 1651103 was found
# Record 174,city name:Santa Vitória do Palmar with city ID: 3449747 was found
# Record 175,city name:Sakakah with city ID: 102527 was found
# Record 176,city name:Lavrentiya with city ID: 4031637 was found
# Record 177,city name:Puerto Madryn with city ID: 3840092 was found
# Record 178,city name:Tabou with city ID: 2281120 was found
# barentsburg, was not found
# Record 179,city name:Pisco with city ID: 3932145 was found
# Record 180,city name:Vestmanna with city ID: 2610343 was found
# Record 181,city name:Sainte-Maxime with city ID: 6445060 was found
# Record 182,city name:Ushtobe with city ID: 1517637 was found
# paucartambo, was not found
# Record 183,city name:Rundu with city ID: 3353383 was found
# Record 184,city name:Bailan with city ID: 1728789 was found
# Record 185,city name:Lata with city ID: 2738381 was found
# Record 186,city name:Bundaberg with city ID: 2173323 was found
# Record 187,city name:Urengoy with city ID: 1488414 was found
# bolungarvik, was not found
# Record 188,city name:Hualmay with city ID: 3939761 was found
# Record 189,city name:Stornoway with city ID: 2636790 was found
# Record 190,city name:Sayyan with city ID: 70979 was found
# Record 191,city name:Carnarvon with city ID: 2074865 was found
# Record 192,city name:Iracoubo with city ID: 3381428 was found
# Record 193,city name:Mar del Plata with city ID: 3430863 was found
# Record 194,city name:Tura with city ID: 1254046 was found
# Record 195,city name:Kavaratti with city ID: 1267390 was found
# Record 196,city name:Macas with city ID: 3654541 was found
# Record 197,city name:Alta Floresta with city ID: 6316343 was found
# Record 198,city name:Cabo San Lucas with city ID: 3985710 was found
# Record 199,city name:Lalibela with city ID: 332288 was found
# Record 200,city name:San Patricio with city ID: 3985168 was found
# Record 201,city name:Saurimo with city ID: 145531 was found
# Record 202,city name:Gorontalo with city ID: 1643837 was found
# Record 203,city name:Thung Song with city ID: 1150085 was found
# saleaula, was not found
# Record 204,city name:Sukhumi with city ID: 611847 was found
# Record 205,city name:Eyl with city ID: 60019 was found
# Record 206,city name:Almaznyy with city ID: 582447 was found
# Record 207,city name:Kapaa with city ID: 5848280 was found
# Record 208,city name:Faanui with city ID: 4034551 was found
# Record 209,city name:Celendín with city ID: 3698608 was found
# Record 210,city name:Pangnirtung with city ID: 6096551 was found
# Record 211,city name:Milove with city ID: 701104 was found
# Record 212,city name:Bentiu with city ID: 377472 was found
# Record 213,city name:Morón with city ID: 3430545 was found
# Record 214,city name:Hasaki with city ID: 2112802 was found
# Record 215,city name:Impfondo with city ID: 2259655 was found
# Record 216,city name:Westerland with city ID: 2810284 was found
# Record 217,city name:Port Lincoln with city ID: 2063036 was found
# Record 218,city name:Mahabalipuram with city ID: 1263997 was found
# Record 219,city name:Perth with city ID: 2063523 was found
# Record 220,city name:Norman Wells with city ID: 6089245 was found
# Record 221,city name:Ibrā’ with city ID: 287832 was found
# play cu, was not found
# Record 222,city name:Tashtagol with city ID: 1490042 was found
# Record 223,city name:Belaya Gora with city ID: 2126785 was found
# rungata, was not found
# ituni, was not found
# Record 224,city name:Linhares with city ID: 3458498 was found
# Record 225,city name:Vila with city ID: 7117100 was found
# Record 226,city name:Aklavik with city ID: 5882953 was found
# Record 227,city name:Oriximiná with city ID: 3393471 was found
# Record 228,city name:Leningradskiy with city ID: 2123814 was found
# Record 229,city name:Ancud with city ID: 3899695 was found
# Record 230,city name:Smirnykh with city ID: 2121126 was found
# Record 231,city name:Pevek with city ID: 2122090 was found
# Record 232,city name:Ballina with city ID: 2177069 was found
# Record 233,city name:Rutana Province with city ID: 434147 was found
# Record 234,city name:Kitimat with city ID: 5993072 was found
# Record 235,city name:Sakhnovshchyna with city ID: 694919 was found
# Record 236,city name:Siverek with city ID: 300614 was found
# Record 237,city name:Hofn with city ID: 2630299 was found
# Record 238,city name:Sfântu Gheorghe with city ID: 667303 was found
# Record 239,city name:Skibbereen with city ID: 2961459 was found
# Record 240,city name:Leh with city ID: 1264976 was found
# bur gabo, was not found
# tumannyy, was not found
# Record 241,city name:Hong Kong with city ID: 1819729 was found
# Record 242,city name:Kidal with city ID: 2455290 was found
# Record 243,city name:Khatanga with city ID: 2022572 was found
# Record 244,city name:Tcholliré with city ID: 2221607 was found
# Record 245,city name:Upata with city ID: 3625710 was found
# Record 246,city name:Batemans Bay with city ID: 2176639 was found
# Record 247,city name:Guerrero Negro with city ID: 4021858 was found
# Record 248,city name:Hede with city ID: 1808744 was found
# Record 249,city name:Bethel with city ID: 5282297 was found
# Record 250,city name:Brownfield with city ID: 5517675 was found
# Record 251,city name:Grand-Santi with city ID: 3381538 was found
# Record 252,city name:Phayakkhaphum Phisai with city ID: 1607763 was found
# Record 253,city name:Arak with city ID: 143127 was found
# Record 254,city name:Mormugao with city ID: 1263494 was found
# Record 255,city name:‘Ewa Beach with city ID: 5855051 was found
# Record 256,city name:Realeza with city ID: 3451783 was found
# Record 257,city name:Diffa with city ID: 2445704 was found
# Record 258,city name:Bonfim with city ID: 3405215 was found
# Record 259,city name:São Filipe with city ID: 3374210 was found
# Record 260,city name:Nerchinsk with city ID: 2019326 was found
# Record 261,city name:Kuril'sk with city ID: 2123979 was found
# Record 262,city name:Joshīmath with city ID: 1268814 was found
# Record 263,city name:Manavālakurichi with city ID: 1263942 was found
# Record 264,city name:Komatipoort with city ID: 988290 was found
# Record 265,city name:Saint George with city ID: 5546220 was found
# Record 266,city name:Nioki with city ID: 2311968 was found
# Record 267,city name:Arrifes with city ID: 3373329 was found
# Record 268,city name:Nouakchott with city ID: 2377450 was found
# Record 269,city name:Lagos with city ID: 2332453 was found
# Record 270,city name:Gīdam with city ID: 1271215 was found
# Record 271,city name:Matadi with city ID: 2313002 was found
# Record 272,city name:Khonsa with city ID: 1266668 was found
# satitoa, was not found
# Record 273,city name:Inuvik with city ID: 5983607 was found
# Record 274,city name:Nebolchi with city ID: 523051 was found
# Record 275,city name:Sola with city ID: 2134814 was found
# Record 276,city name:Miguel Hidalgo with city ID: 3827408 was found
# Record 277,city name:San Andrés with city ID: 3670218 was found
# Record 278,city name:Nanortalik with city ID: 3421765 was found
# bolshoy tsaryn, was not found
# Record 279,city name:Tūkrah with city ID: 88834 was found
# Record 280,city name:São João da Barra with city ID: 3448903 was found
# Record 281,city name:Laas with city ID: 3175096 was found
# Record 282,city name:Iseyin with city ID: 2337181 was found
# Record 283,city name:Pajapan with city ID: 3522186 was found
# Record 284,city name:Bar Harbor with city ID: 4957320 was found
# Record 285,city name:Languyan with city ID: 1707511 was found
# Record 286,city name:Puerto Peñasco with city ID: 3991347 was found
# Record 287,city name:Ust-Kuyga with city ID: 2013921 was found
# Record 288,city name:Portland with city ID: 5746545 was found
# Record 289,city name:Manzanillo with city ID: 3547867 was found
# Record 290,city name:Jinchang with city ID: 1805733 was found
# lolua, was not found
# Record 291,city name:Port Macquarie with city ID: 2152659 was found
# Record 292,city name:Tuktoyaktuk with city ID: 6170031 was found
# buqayq, was not found
# Record 293,city name:Orchard Homes with city ID: 5670128 was found
# saryshagan, was not found
# Record 294,city name:Matamoros with city ID: 3996426 was found
# Record 295,city name:Inhambane with city ID: 1045114 was found
# Record 296,city name:Teya with city ID: 1489656 was found
# Record 297,city name:Las Vegas with city ID: 5506956 was found
# Record 298,city name:Muswellbrook with city ID: 2156034 was found
# Record 299,city name:Padang with city ID: 1633419 was found
# Record 300,city name:Santo Ângelo with city ID: 3449696 was found
# Record 301,city name:Pangody with city ID: 1495626 was found
# Record 302,city name:Jaqué with city ID: 3708432 was found
# Record 303,city name:Luangwa with city ID: 909887 was found
# Record 304,city name:Maragogi with city ID: 3395458 was found
# Record 305,city name:Necochea with city ID: 3430443 was found
# Record 306,city name:Torbay with city ID: 6167817 was found
# Record 307,city name:Vila Franca do Campo with city ID: 3372472 was found
# Record 308,city name:Miramar with city ID: 4164601 was found
# Record 309,city name:Vilyuysk with city ID: 2013392 was found
# Record 310,city name:Baharly with city ID: 162158 was found
# abiy adi, was not found
# Record 311,city name:Bubaque with city ID: 2374583 was found
# Record 312,city name:Tigil' with city ID: 2120612 was found
# Record 313,city name:Kingsport with city ID: 4634662 was found
# Record 314,city name:Flin Flon with city ID: 5954718 was found
# Record 315,city name:Flinders with city ID: 6255012 was found
# Record 316,city name:Fairview with city ID: 5097801 was found
# Record 317,city name:Bandarbeyla with city ID: 64814 was found
# Record 318,city name:Beni Suef with city ID: 359173 was found
# Record 319,city name:Port Hedland with city ID: 2063042 was found
# Record 320,city name:Babati with city ID: 161312 was found
# Record 321,city name:Patacamaya with city ID: 3908339 was found
# Record 322,city name:Vila Velha with city ID: 3445026 was found
# Record 323,city name:Santa Maria with city ID: 3450083 was found
# Record 324,city name:Aripuanã with city ID: 3665202 was found
# tabiauea, was not found
# Record 325,city name:Saýat with city ID: 1218436 was found
# Record 326,city name:Chapais with city ID: 5919850 was found
# umzimvubu, was not found
# Record 327,city name:Ciparay with city ID: 1646281 was found
# Record 328,city name:Salalah with city ID: 286621 was found
# Record 329,city name:Bara with city ID: 2347758 was found
# Record 330,city name:Solenzo with city ID: 2355404 was found
# Record 331,city name:Tairua with city ID: 2182010 was found
# Record 332,city name:Elko with city ID: 5703673 was found
# Record 333,city name:Udangudi with city ID: 1253972 was found
# Record 334,city name:Booué with city ID: 2401495 was found
# marcona, was not found
# Record 335,city name:Mersing with city ID: 1732826 was found
# Record 336,city name:Beringovskiy with city ID: 2126710 was found
# Record 337,city name:Altus with city ID: 4529292 was found
# Record 338,city name:Corner Brook with city ID: 5927969 was found
# Record 339,city name:Quibor with city ID: 3629419 was found
# Record 340,city name:Chipinge with city ID: 893549 was found
# Record 341,city name:Kalmunai with city ID: 1242110 was found
# Record 342,city name:Omsukchan with city ID: 2122493 was found
# Record 343,city name:Guarda with city ID: 2738785 was found
# Record 344,city name:Dubbo with city ID: 2168305 was found
# Record 345,city name:Usinsk with city ID: 863061 was found
# Record 346,city name:Isangel with city ID: 2136825 was found
# Record 347,city name:Manoel Urbano with city ID: 3663495 was found
# haapu, was not found
# Record 348,city name:Ginir with city ID: 336454 was found
# Record 349,city name:Hervey Bay with city ID: 2146219 was found
# Record 350,city name:Biltine with city ID: 244878 was found
# Record 351,city name:Visby with city ID: 2662689 was found
# borama, was not found
# Record 352,city name:Fare with city ID: 4034496 was found
# Record 353,city name:Horsham with city ID: 2646557 was found
# Record 354,city name:Forio with city ID: 3176748 was found
# Record 355,city name:Sai Buri with city ID: 1606851 was found
# Record 356,city name:Altamira with city ID: 3407882 was found
# Record 357,city name:Pizarro with city ID: 3672086 was found
# Record 358,city name:Monticello with city ID: 5038045 was found
# Record 359,city name:Riyadh with city ID: 108410 was found
# Record 360,city name:Lerwick with city ID: 2644605 was found
# Record 361,city name:Livingston with city ID: 2644204 was found
# Record 362,city name:Tigre with city ID: 3427761 was found
# shchuchye, was not found
# Record 363,city name:Tiksi with city ID: 2015306 was found
# Record 364,city name:Kahului with city ID: 5847411 was found
# Record 365,city name:Arlit with city ID: 2447513 was found
# Record 366,city name:Majagual with city ID: 3675637 was found
# Record 367,city name:Talnakh with city ID: 1490256 was found
# Record 368,city name:Nuuk with city ID: 3421319 was found
# Record 369,city name:Bouca with city ID: 2387890 was found
# Record 370,city name:Marawi with city ID: 1701054 was found
# Record 371,city name:Tezu with city ID: 1254709 was found
# Record 372,city name:Coquimbo with city ID: 3893629 was found
# Record 373,city name:Roald with city ID: 3141667 was found
# guajara-mirim, was not found
# Record 374,city name:Dicabisagan with city ID: 1715015 was found
# Record 375,city name:Lagoa with city ID: 3372964 was found
# Record 376,city name:Cayenne with city ID: 3382160 was found
# Record 377,city name:Kargil with city ID: 1267776 was found
# Record 378,city name:Natal with city ID: 3394023 was found
# Record 379,city name:Mordovo with city ID: 525365 was found
# Record 380,city name:Lorengau with city ID: 2092164 was found
# Record 381,city name:Krasnosel'kup with city ID: 1502073 was found
# grand river south east, was not found
# Record 382,city name:Voznesen'ye with city ID: 471160 was found
# Record 383,city name:Omboué with city ID: 2396853 was found
# Record 384,city name:Vallenar with city ID: 3868633 was found
# Record 385,city name:Ucluelet with city ID: 6171633 was found
# Record 386,city name:Uvat with city ID: 1487939 was found
# Record 387,city name:Avera with city ID: 4231997 was found
# Record 388,city name:Abu Samrah with city ID: 172515 was found
# taburi, was not found
# Record 389,city name:Port-de-Bouc with city ID: 6447156 was found
# Record 390,city name:Māndalgarh with city ID: 1263911 was found
# Record 391,city name:Alamosa with city ID: 5411479 was found
# Record 392,city name:Dingle with city ID: 1714733 was found
# Record 393,city name:Rawson with city ID: 3839307 was found
# Record 394,city name:Vrangel' with city ID: 2013258 was found
# Record 395,city name:Kapasan with city ID: 8070821 was found
# Record 396,city name:Calama with city ID: 3897347 was found
# Record 397,city name:Tuzha with city ID: 480085 was found
# Record 398,city name:Asău with city ID: 686090 was found
# Record 399,city name:Waitara with city ID: 2208091 was found
# Record 400,city name:Algiers with city ID: 2507480 was found
# Record 401,city name:Salym with city ID: 1493162 was found
# Record 402,city name:Oktyabr'skoye with city ID: 515805 was found
# Record 403,city name:Narasannapeta with city ID: 1261853 was found
# Record 404,city name:Sørland with city ID: 3137469 was found
# Record 405,city name:Moose Factory with city ID: 6078372 was found
# Record 406,city name:Kazanskoye with city ID: 1504019 was found
# Record 407,city name:Puerto Escondido with city ID: 3520994 was found
# Record 408,city name:Vanimo with city ID: 2084442 was found
# paradwip, was not found
# Record 409,city name:Yüksekova with city ID: 296173 was found
# Record 410,city name:Kokopo with city ID: 2093685 was found
# jiddah, was not found
# Record 411,city name:Bandundu Province with city ID: 2317397 was found
# Record 412,city name:North Shore with city ID: 2185964 was found
# formoso do araguaia, was not found
# Record 413,city name:Ziarat with city ID: 1162094 was found
# Record 414,city name:Neiafu with city ID: 4032420 was found
# tsihombe, was not found
# Record 415,city name:Conroe with city ID: 4682991 was found
# Record 416,city name:Aykhal with city ID: 2027296 was found
# Record 417,city name:Muros with city ID: 3115824 was found
# alotau, was not found
# Record 418,city name:Great Yarmouth with city ID: 2647984 was found
# Record 419,city name:Longyan with city ID: 1802276 was found
# Record 420,city name:Sompeta with city ID: 1255816 was found
# Record 421,city name:Onega with city ID: 515246 was found
# mbacke, was not found
# Record 422,city name:General Pico with city ID: 3855075 was found
# Record 423,city name:Pringsewu with city ID: 1630639 was found
# sogdiondon, was not found
# Record 424,city name:Guozhen with city ID: 1809263 was found
# Record 425,city name:Cartagena with city ID: 3687238 was found
# Record 426,city name:Port Augusta with city ID: 2063056 was found
# Record 427,city name:Riohacha with city ID: 3670745 was found
# Record 428,city name:Victoria Point with city ID: 2145214 was found
# Record 429,city name:Malatya Province with city ID: 304919 was found
# Record 430,city name:Praia da Vitória with city ID: 3372760 was found
# Record 431,city name:Armidale with city ID: 2177671 was found
# Record 432,city name:Orhei with city ID: 617638 was found
# Record 433,city name:Porto de Moz with city ID: 3391387 was found
# halalo, was not found
# Record 434,city name:Rockhampton with city ID: 2151437 was found
# Record 435,city name:Baculin with city ID: 1729469 was found
# Record 436,city name:Unity with city ID: 6172009 was found
# Record 437,city name:Ilebo with city ID: 215976 was found
# Record 438,city name:Caborca with city ID: 3996893 was found
# Record 439,city name:Ayan with city ID: 2027316 was found
# Record 440,city name:Zhangjiakou with city ID: 2033196 was found
# Record 441,city name:Lethem with city ID: 3379316 was found
# Record 442,city name:Canberra with city ID: 2172517 was found
# Record 443,city name:Codrington with city ID: 2171099 was found
# Record 444,city name:Ivybridge with city ID: 2645988 was found
# Record 445,city name:Āreka with city ID: 343593 was found
# Record 446,city name:Katsuura with city ID: 2112309 was found
# Record 447,city name:Cap Malheureux with city ID: 934649 was found
# Record 448,city name:Huarmey with city ID: 3939168 was found
# Record 449,city name:Buguruslan with city ID: 571159 was found
# Record 450,city name:Nemuro with city ID: 2128975 was found
# Record 451,city name:Lüshunkou with city ID: 1801722 was found
# Record 452,city name:Zuwārah with city ID: 2208425 was found
# dera din panah, was not found
# Record 453,city name:Senneterre with city ID: 6144195 was found
# Record 454,city name:Río Gallegos with city ID: 3838859 was found
# Record 455,city name:Faya with city ID: 110690 was found
# Record 456,city name:Ozernovskiy with city ID: 2122293 was found
# Record 457,city name:Carlyle with city ID: 4235229 was found
# Record 458,city name:Anchorage with city ID: 5879400 was found
# Record 459,city name:Foz with city ID: 3122172 was found
# Record 460,city name:Sargatskoye with city ID: 1493004 was found
# Record 461,city name:Sarrebourg with city ID: 2975967 was found
# Record 462,city name:Souris with city ID: 6151456 was found
# Record 463,city name:Bougouni with city ID: 2459775 was found
# Record 464,city name:Fort Nelson with city ID: 5955902 was found
# Record 465,city name:Fukuechō with city ID: 1863997 was found
# Record 466,city name:Presidencia Roque Sáenz Peña with city ID: 3840300 was found
# Record 467,city name:Diplo with city ID: 1179758 was found
# Record 468,city name:Blatec with city ID: 792553 was found
# Record 469,city name:Katobu with city ID: 1640972 was found
# Record 470,city name:Isla Mujeres with city ID: 3526756 was found
# Record 471,city name:Senanga with city ID: 898947 was found
# Record 472,city name:Wajima with city ID: 1848976 was found
# Record 473,city name:Bāgli with city ID: 1277874 was found
# Record 474,city name:Teguise with city ID: 2510573 was found
# Record 475,city name:Tutóia with city ID: 3385899 was found
# Record 476,city name:Savannah Bight with city ID: 3601402 was found
# Record 477,city name:Karratha with city ID: 6620339 was found
# Record 478,city name:Crixás with city ID: 3465145 was found
# Record 479,city name:Zhigansk with city ID: 2012530 was found
# Record 480,city name:Shimoda with city ID: 1852357 was found
# Record 481,city name:Aix-les-Bains with city ID: 3038350 was found
# louisbourg, was not found
# Record 482,city name:Miandrivazo with city ID: 1059051 was found
# Record 483,city name:Narsaq with city ID: 3421719 was found
# Record 484,city name:Marabu with city ID: 1738050 was found
# Record 485,city name:Cockburn Town with city ID: 3576994 was found
# Record 486,city name:Dwārka with city ID: 1272140 was found
# Record 487,city name:Waipawa with city ID: 2206874 was found
# Record 488,city name:Puerto del Rosario with city ID: 2512186 was found
# Record 489,city name:West Bay with city ID: 3580477 was found
# Record 490,city name:Nivala with city ID: 644499 was found
# Record 491,city name:Dondo with city ID: 1024696 was found
# Record 492,city name:Rabat with city ID: 2538474 was found
# Record 493,city name:Bodden Town with city ID: 3580733 was found
# Record 494,city name:Redlands with city ID: 5386754 was found
# Record 495,city name:Seinäjoki with city ID: 637219 was found
# Record 496,city name:Valea Ursului with city ID: 663331 was found
# Record 497,city name:Sulangan with city ID: 1685422 was found
# Record 498,city name:Ritchie with city ID: 961226 was found
# Record 499,city name:Cody with city ID: 5821593 was found
# Record 500,city name:Nioro with city ID: 2412408 was found
# Record 501,city name:Price with city ID: 5545269 was found
# Record 502,city name:Luhyny with city ID: 702679 was found
# Record 503,city name:Saint-François with city ID: 2980080 was found
# Record 504,city name:Prieska with city ID: 964090 was found
# Record 505,city name:Launceston with city ID: 2160517 was found
# Record 506,city name:Lluta with city ID: 3936088 was found
# Record 507,city name:Stromness with city ID: 2636638 was found
# Record 508,city name:Saint-Augustin with city ID: 6137462 was found
# Record 509,city name:Bontang with city ID: 1648186 was found
# Record 510,city name:Ust'-Uda with city ID: 2013865 was found
# Record 511,city name:Dudinka with city ID: 1507116 was found
# Record 512,city name:Christchurch with city ID: 2192362 was found
# Record 513,city name:Caceres with city ID: 2520610 was found
# Record 514,city name:High Level with city ID: 5975004 was found
# Record 515,city name:Gannan with city ID: 2037311 was found
# Record 516,city name:Along with city ID: 1278969 was found
# Record 517,city name:Pagudpud with city ID: 1696482 was found
# Record 518,city name:Eureka with city ID: 5563397 was found
# Record 519,city name:Amazar with city ID: 2027806 was found
# Record 520,city name:Yaan with city ID: 2338660 was found
# Record 521,city name:Dori with city ID: 2361082 was found
# Record 522,city name:Ranong with city ID: 1150965 was found
# Record 523,city name:Plouzané with city ID: 2986626 was found
# gurgan, was not found
# jahrom, was not found
# Record 524,city name:Ranau with city ID: 1733502 was found
# Record 525,city name:Vendychany with city ID: 690032 was found
# Record 526,city name:Yulara with city ID: 6355222 was found
# viligili, was not found
# Record 527,city name:Arrondissement du Havre with city ID: 3013633 was found
# Record 528,city name:Dali with city ID: 1814093 was found
# Record 529,city name:Portree with city ID: 2640006 was found
# Record 530,city name:Kendari with city ID: 1640344 was found
# Record 531,city name:Deer Lake with city ID: 5937252 was found
# Record 532,city name:Tevaitoa with city ID: 4033375 was found
# hihifo, was not found
# Record 533,city name:Nyrob with city ID: 516588 was found
# Record 534,city name:Buritis with city ID: 3468732 was found
# Record 535,city name:Paamiut with city ID: 3421193 was found
# Record 536,city name:Tual with city ID: 1623197 was found
# Record 537,city name:Changde with city ID: 1791121 was found
# Record 538,city name:Ekenäs with city ID: 660325 was found
# Record 539,city name:Mt. Pleasant with city ID: 4588165 was found
# Record 540,city name:Bowen with city ID: 2174444 was found
# Record 541,city name:Alghero with city ID: 3183284 was found
# Record 542,city name:Puerto Cabezas with city ID: 3617154 was found
# Record 543,city name:Charters Towers with city ID: 2171722 was found
# Record 544,city name:Sinjai with city ID: 1626895 was found
# Record 545,city name:Chokurdakh with city ID: 2126123 was found
# Record 546,city name:Libreville with city ID: 2399697 was found
# Record 547,city name:Svarstad with city ID: 7626348 was found
# Record 548,city name:Dourbali with city ID: 2433055 was found
# Record 549,city name:The Valley with city ID: 3573374 was found
# sentyabrskiy, was not found
# Data Extract Completed

# %%
#Create a DataFrame to hold the weather information
weather_data_df=pd.DataFrame({"City ID":city_id, 
                              "City Name":city_name, 
                              "Country Code":country,
                              "Date": date,
                              "Latitude":latitude,
                              "Longitude":longitude, 
                              "Humidity %":humidity, 
                              "Temperature (F)":temperature,
                              "Wind Speed (mph)":wind_speed, 
                              "Cloudiness %":cloudiness})

weather_data_df
# Out:
#      City ID       City Name Country Code      Date  Latitude  Longitude  \
# 0    2075265       Busselton           AU  05/03/20    -33.65     115.33
# 1     935215  Saint-Philippe           RE  05/03/20    -21.36      55.77
# 2    5404476           Ukiah           US  05/03/20     39.15    -123.21
# 3    2025256        Chumikan           RU  05/03/20     54.72     135.31
# 4    1015776      Bredasdorp           ZA  05/03/20    -34.53      20.04
# ..       ...             ...          ...       ...       ...        ...
# 544  2126123      Chokurdakh           RU  05/03/20     70.63     147.92
# 545  2399697      Libreville           GA  05/03/20      0.39       9.45
# 546  7626348        Svarstad           NO  05/03/20     59.40       9.97
# 547  2433055        Dourbali           TD  05/03/20     11.81      15.86
# 548  3573374      The Valley           AI  05/03/20     18.22     -63.06
#
#      Humidity %  Temperature (F)  Wind Speed (mph)  Cloudiness %
# 0            79            65.80             17.90            77
# 1            78            71.08              5.82            20
# 2            33            65.64             10.29             1
# 3            88            33.24             16.75            17
# 4            93            55.40              1.12            73
# ..          ...              ...               ...           ...
# 544          94             9.97              5.21            17
# 545          83            84.20              6.93            20
# 546           4            38.32              6.80             9
# 547          24            94.08              4.61           100
# 548          74            81.45              8.05            20
#
# [549 rows x 10 columns]

# %%
#Create a file with all the weather information (csv)
weather_data_df.to_csv("weather_data.csv",encoding="utf-8", index=False)

# %% [markdown]
# Scatter Plots

# %%
# Create a scatter plot for temperature & latitude
x_values = weather_data_df["Latitude"]
y_values = weather_data_df["Temperature (F)"]
plt.scatter(x_values,y_values)
plt.title(f"City Latitude & Temperature (F)")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")

plt.savefig("latitude_vs_temperature.png")
plt.show()

# %% [markdown]
# Observations
# The City Latitude & Temperature scatter plot makes a good representation of the earth's weather in general. Cities with higher tempetures cluster around the equator, between 0 and 20 degrees, and the tempeture drops as cities get closer to the earth's north and south poles around -40 and around 60 degrees.

# %%
# Create a scatter plot for humidity (%) & Latitude
x_values = weather_data_df["Latitude"]
y_values = weather_data_df["Humidity %"]
plt.scatter(x_values,y_values)
plt.title(f" City Latitude & Humidity % ")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")

plt.savefig("humidity_vs_latitude.png")
plt.show()

# %% [markdown]
# Observations
# There is no appearent correlation between humidity and latitude in the City Latitude & Humidity scatter plot. However, we can see that many cities have humidity higher than 60%.It would be interesting to see the humidity percentage in the summer vs the winter.

# %%
# Create a scatter plot for cloudiness (%) & latitude
x_values = weather_data_df["Latitude"]
y_values = weather_data_df["Cloudiness %"]
plt.scatter(x_values,y_values)
plt.title(f" City Latitude & Cloudiness %")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")

plt.savefig("cloudiness_vs_latitude.png")
plt.show()

# %% [markdown]
# Observations
# There is no appearent correlation between cloudiness and latitude in the City Latitude & Cloudiness scatter plot. However, we can see some linear cloudiness clusters at 0%, 40%, 75%, and 100% across all latitudes.

# %%
# Create a scatter plot for wind speed (mph) & latitude
x_values = weather_data_df["Latitude"]
y_values = weather_data_df["Wind Speed (mph)"]
plt.scatter(x_values,y_values)
plt.title(f" City Latitude & Wind Speed (mph)")
plt.xlabel("Latitude")
plt.ylabel(" Wind Speed (mph)")

plt.savefig("wind_speed_vs_latitude.png")
plt.show()

# %% [markdown]
# Observations
# There is no appearent correlation between wind speed and latitude in the City Latitude & Wind Speed scatter plot, however it appears for most cities the wind speed is less than 15 mph. There are also a couple of wind speed outliers in the northern hemisphere.

# %% [markdown]
# Northern and Southern Hemisphere Plots

# %%
#Set two seperate list with northern hemisphere and southern hemisphere data
north_hem=weather_data_df.loc[weather_data_df["Latitude"] >= 0,:]
south_hem=weather_data_df.loc[weather_data_df["Latitude"] < 0,:]

south_hem.head()
# Out:
#    City ID       City Name Country Code      Date  Latitude  Longitude  \
# 0  2075265       Busselton           AU  05/03/20    -33.65     115.33
# 1   935215  Saint-Philippe           RE  05/03/20    -21.36      55.77
# 4  1015776      Bredasdorp           ZA  05/03/20    -34.53      20.04
# 6   934322       Mahébourg           MU  05/03/20    -20.41      57.70
# 7  3871336        Santiago           CL  05/03/20    -33.46     -70.65
#
#    Humidity %  Temperature (F)  Wind Speed (mph)  Cloudiness %
# 0          79            65.80             17.90            77
# 1          78            71.08              5.82            20
# 4          93            55.40              1.12            73
# 6          88            75.20              9.17            40
# 7          45            66.20              4.27           100

# %%
#Plot regression line on scatter plots
def plot_regression(x_values,y_values,x_axis_label,y_axis_label, hemisphere):
    (slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    regress_values = x_values * slope + intercept
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.title(f" {hemisphere}-City {x_axis_label} & {y_axis_label}")
    plt.xlabel(x_axis_label)
    plt.ylabel(y_axis_label)
    print(f"The r-squared is: {rvalue}")
    print(line_eq)
    plt.show()

# %%
#plot regression line for northern hemisphere and temperature
plot_regression(north_hem["Latitude"],north_hem["Temperature (F)"],"Latitude","Temperature (F)", "Northern Hemisphere")

plt.savefig('north_temp.png')
# Out:
# The r-squared is: -0.8858849598618039
# y = -0.91x + 94.15

# %%
#plot regression line for southern hemisphere and temperature
plot_regression(south_hem["Latitude"],south_hem["Temperature (F)"],"Latitude","Temperature (F)", "Southern Hemisphere")

plt.savefig('south_temp.png')
# Out:
# The r-squared is: 0.7615873499503534
# y = 0.63x + 80.33

# %%
#plot regression line for northern hemisphere and humidity
plot_regression(north_hem["Latitude"],north_hem["Humidity %"],"Latitude","Humidity %", "Northern Hemisphere")

plt.savefig('north_humidity.png')
# Out:
# The r-squared is: 0.1803212198583595
# y = 0.22x + 59.63

# %%
#plot regression line for southern hemisphere and humidity
plot_regression(south_hem["Latitude"],south_hem["Humidity %"],"Latitude","Humidity %", "Southern Hemisphere")

plt.savefig('south_humidity.png')
# Out:
# The r-squared is: 0.02867010890361562
# y = 0.04x + 74.17

# %%
#plot regression line for northern hemisphere and cloudiness
plot_regression(north_hem["Latitude"],north_hem["Cloudiness %"],"Latitude","Cloudiness %", "Northern Hemisphere")

plt.savefig('north_cloudiness.png')
# Out:
# The r-squared is: 0.054826415276691805
# y = 0.1x + 49.16

# %%
#plot regression line for southern hemisphere and cloudiness
plot_regression(south_hem["Latitude"],south_hem["Cloudiness %"],"Latitude","Cloudiness %", "Southern Hemisphere")

plt.savefig('south_cloudiness.png')
# Out:
# The r-squared is: -0.005323195980293666
# y = -0.01x + 48.76

# %%
#plot pregression line for northern hemisphere and wind speed
plot_regression(north_hem["Latitude"],north_hem["Wind Speed (mph)"],"Latitude","Wind Speed (mph)", "Northern Hemisphere")

plt.savefig('north_windspeed.png')
# Out:
# The r-squared is: 0.06494035261484697
# y = 0.02x + 7.42

# %%
#plot regression line for southern hemisphere and wind speed
plot_regression(south_hem["Latitude"],south_hem["Wind Speed (mph)"],"Latitude","Wind Speed (mph)", "Southern Hemisphere")

plt.savefig('south_windspeed.png')
# Out:
# The r-squared is: -0.07703221802443277
# y = -0.03x + 5.76
