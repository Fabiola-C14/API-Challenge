# %% [markdown]
# # WeatherPy

# %%
#Import pandas, requests, pprint, citipy, config key

import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
import time
import scipy.stats as st
import json
import pprint
from citipy import citipy
from datetime import datetime
from config import api_key

# Create outbound file (CSV)
output_data_file = "data_city_list.csv"

# %%
# Set coordinates
lat_coord = (-90, 90)
lng_coord = (-180, 180)

#  Create list for longitude, latitude, city and country
lat_lng = []
city_list = []
country_list = []

# Create citites with random latitudes and longitudes
lat = np.random.uniform(low=-90.000, high=90.000, size=1500)
lng = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lng = zip(lat, lng)

# Identify unique cities
for unique_lat_lng in lat_lng:
    city = citipy.nearest_city(unique_lat_lng[0], unique_lat_lng[1]).city_name
    
    
    # Add unique cities to the list
    if city not in city_list:
        city_list.append(city)

len(city_list)
# Out:
# 610

# %%
# Create list to add the variables
city_id= []
city_name = []
country = []
latitude = []
longitude = []
date=[]
humidity = []
temperature = []
wind_speed = []
cloudiness = []
count=0

#Extract weather for various cities from the city list
for city in city_list:
    query_url = f"{url}appid={api_key}&q={city}&units={units}"
    response = requests.get(query_url + city).json()
    try:
        cityid=response["id"]
        cityname=response["name"]
        countrycode=response["sys"]["country"]
        lat=response["coord"]["lat"]
        long=response["coord"]["lon"]
        weatherdate =(datetime.fromtimestamp(response['dt'])).strftime('%m/%d/%y')
        hum=response["main"]["humidity"]
        temp=response["main"]["temp"]
        windspeed=response["wind"]["speed"]
        cloud=response["clouds"]["all"]
        
        city_id.append(int(cityid))
        city_name.append(cityname)
        country.append(countrycode)
        latitude.append(lat)
        longitude.append(long)
        date.append(weatherdate)
        humidity.append(hum)
        temperature.append(temp)
        wind_speed.append(windspeed)
        cloudiness.append(cloud)
        
        #Set a count of records found
        count=count+1
        
        print(f"Record {count},city name:{cityname} with city ID: {cityid} was found")
    except:
        print(f"{city}, was not found")
        pass
# Out:
# Record 1,city name:Berlevåg with city ID: 780687 was found
# Record 2,city name:Busselton with city ID: 2075265 was found
# Record 3,city name:Penzance with city ID: 2640377 was found
# Record 4,city name:Rikitea with city ID: 4030556 was found
# Record 5,city name:Hong Kong with city ID: 1819729 was found
# Record 6,city name:Tilichiki with city ID: 2120591 was found
# Record 7,city name:Praia da Vitória with city ID: 3372760 was found
# Record 8,city name:Chui with city ID: 3443061 was found
# Record 9,city name:Port Hawkesbury with city ID: 6111867 was found
# Record 10,city name:Ceres with city ID: 5335650 was found
# Record 11,city name:Upernavik with city ID: 3418910 was found
# Record 12,city name:Fairview with city ID: 5097801 was found
# Record 13,city name:Cidreira with city ID: 3466165 was found
# Record 14,city name:Mount Gambier with city ID: 2156643 was found
# Record 15,city name:Bredasdorp with city ID: 1015776 was found
# Record 16,city name:Dingzhou with city ID: 1812728 was found
# Record 17,city name:Lagoa with city ID: 3372964 was found
# Record 18,city name:Lompoc with city ID: 5367788 was found
# Record 19,city name:Punta Arenas with city ID: 3874787 was found
# Record 20,city name:Lamar with city ID: 4705086 was found
# Record 21,city name:Jamestown with city ID: 5122534 was found
# Record 22,city name:Bluff with city ID: 2206939 was found
# Record 23,city name:Okhotsk with city ID: 2122605 was found
# Record 24,city name:Albany with city ID: 5106841 was found
# Record 25,city name:Port Alfred with city ID: 964432 was found
# Record 26,city name:Atbasar with city ID: 1526038 was found
# Record 27,city name:Barbalha with city ID: 3406442 was found
# Record 28,city name:Kununurra with city ID: 2068110 was found
# Record 29,city name:Coahuayana Viejo with city ID: 4013679 was found
# Record 30,city name:Hobart with city ID: 2163355 was found
# Record 31,city name:Usvyaty with city ID: 477774 was found
# samusu, was not found
# Record 32,city name:Saint-Philippe with city ID: 935215 was found
# Record 33,city name:Soyo with city ID: 2236967 was found
# Record 34,city name:Pedro II with city ID: 3392431 was found
# Record 35,city name:Kristinestad with city ID: 650769 was found
# Record 36,city name:Bushehr with city ID: 139817 was found
# Record 37,city name:Bonavista with city ID: 5905393 was found
# Record 38,city name:Mataura with city ID: 6201424 was found
# Record 39,city name:Fereydūnkenār with city ID: 134602 was found
# Record 40,city name:Lata with city ID: 2738381 was found
# Record 41,city name:Puerto del Rosario with city ID: 2512186 was found
# Record 42,city name:Pevek with city ID: 2122090 was found
# Record 43,city name:Kapaa with city ID: 5848280 was found
# Record 44,city name:Camapuã with city ID: 3468020 was found
# Record 45,city name:Tuktoyaktuk with city ID: 6170031 was found
# Record 46,city name:San Miguel de Cozumel with city ID: 3530103 was found
# Record 47,city name:Hilo with city ID: 5855927 was found
# Record 48,city name:Hermanus with city ID: 3366880 was found
# Record 49,city name:Ulaangom with city ID: 1515029 was found
# Record 50,city name:Lázaro Cárdenas with city ID: 4026082 was found
# Record 51,city name:Mujiayingzi with city ID: 2035707 was found
# Record 52,city name:Katangli with city ID: 2122783 was found
# Record 53,city name:Heiligenhafen with city ID: 2907589 was found
# Record 54,city name:Ushuaia with city ID: 3833367 was found
# Record 55,city name:Pangnirtung with city ID: 6096551 was found
# Record 56,city name:Joshīmath with city ID: 1268814 was found
# Record 57,city name:Philadelphia with city ID: 4560349 was found
# Record 58,city name:Longyearbyen with city ID: 2729907 was found
# Record 59,city name:Zverinogolovskoye with city ID: 1484943 was found
# Record 60,city name:Khatanga with city ID: 2022572 was found
# Record 61,city name:Aklavik with city ID: 5882953 was found
# Record 62,city name:San Rafael with city ID: 3836669 was found
# belushya guba, was not found
# toliary, was not found
# Record 63,city name:East Wenatchee Bench with city ID: 5793272 was found
# Record 64,city name:Saint Paul Harbor with city ID: 5866583 was found
# Record 65,city name:Arbazh with city ID: 581228 was found
# Record 66,city name:Vaini with city ID: 4032243 was found
# Record 67,city name:Aksarka with city ID: 1512019 was found
# Record 68,city name:Pisco with city ID: 3932145 was found
# Record 69,city name:New Norfolk with city ID: 2155415 was found
# Record 70,city name:Grand Gaube with city ID: 934479 was found
# Record 71,city name:Anadyr with city ID: 2127202 was found
# Record 72,city name:Laas with city ID: 3175096 was found
# Record 73,city name:Tabou with city ID: 2281120 was found
# Record 74,city name:Dikson with city ID: 1507390 was found
# Record 75,city name:Arlit with city ID: 2447513 was found
# Record 76,city name:Narsaq with city ID: 3421719 was found
# Record 77,city name:Flinders with city ID: 6255012 was found
# Record 78,city name:Ribeira Grande with city ID: 3372707 was found
# Record 79,city name:Esperance with city ID: 2071860 was found
# Record 80,city name:Sabha with city ID: 2212775 was found
# Record 81,city name:Barrow with city ID: 5880054 was found
# Record 82,city name:Junín with city ID: 3853354 was found
# Record 83,city name:Katsuura with city ID: 2112309 was found
# Record 84,city name:Eloy with city ID: 5294167 was found
# Record 85,city name:Port Macquarie with city ID: 2152659 was found
# Record 86,city name:Saskylakh with city ID: 2017155 was found
# taolanaro, was not found
# Record 87,city name:Norman Wells with city ID: 6089245 was found
# Record 88,city name:Arraial do Cabo with city ID: 3471451 was found
# Record 89,city name:Haimen with city ID: 1809062 was found
# Record 90,city name:Masterton with city ID: 2206890 was found
# Record 91,city name:Mar del Plata with city ID: 3430863 was found
# Record 92,city name:Batagay-Alyta with city ID: 2027042 was found
# Record 93,city name:Manta with city ID: 3654410 was found
# Record 94,city name:Yerbogachën with city ID: 2012956 was found
# Record 95,city name:Ostrovnoy with city ID: 556268 was found
# Record 96,city name:Saint-Augustin with city ID: 6137462 was found
# Record 97,city name:Atuona with city ID: 4020109 was found
# nguiu, was not found
# Record 98,city name:Tiksi with city ID: 2015306 was found
# Record 99,city name:Palauig with city ID: 1696188 was found
# Record 100,city name:Cape Town with city ID: 3369157 was found
# Record 101,city name:Tuatapere with city ID: 2180815 was found
# Record 102,city name:Meulaboh with city ID: 1214488 was found
# Record 103,city name:Hirara with city ID: 1862505 was found
# Record 104,city name:Tari with city ID: 2322495 was found
# Record 105,city name:Romanovka with city ID: 501468 was found
# Record 106,city name:East London with city ID: 1006984 was found
# Record 107,city name:Ciudad Bolivar with city ID: 3645532 was found
# Record 108,city name:Fortuna with city ID: 5563839 was found
# Record 109,city name:Shima with city ID: 1795166 was found
# Record 110,city name:Yellowknife with city ID: 6185377 was found
# Record 111,city name:Zhangjiakou with city ID: 2033196 was found
# Record 112,city name:Carnarvon with city ID: 2074865 was found
# Record 113,city name:Lujiang with city ID: 1802068 was found
# Record 114,city name:Hofn with city ID: 2630299 was found
# Record 115,city name:Westport with city ID: 4845585 was found
# Record 116,city name:Biak with city ID: 1637001 was found
# Record 117,city name:Kolno with city ID: 768785 was found
# kamenskoye, was not found
# Record 118,city name:Ancud with city ID: 3899695 was found
# Record 119,city name:Omsukchan with city ID: 2122493 was found
# Record 120,city name:Jalu with city ID: 86049 was found
# Record 121,city name:Beringovskiy with city ID: 2126710 was found
# sentyabrskiy, was not found
# Record 122,city name:Iqaluit with city ID: 5983720 was found
# Record 123,city name:Takoradze with city ID: 2294915 was found
# Record 124,city name:Nome with city ID: 5870133 was found
# Record 125,city name:Saint George with city ID: 5546220 was found
# Record 126,city name:Maniwaki with city ID: 6065262 was found
# Record 127,city name:Ginir with city ID: 336454 was found
# Record 128,city name:Bengkulu with city ID: 1649150 was found
# Record 129,city name:Kwinana with city ID: 2068079 was found
# Record 130,city name:Nantucket with city ID: 4944903 was found
# Record 131,city name:Chengzhong with city ID: 1786640 was found
# Record 132,city name:Butaritari with city ID: 2110227 was found
# Record 133,city name:Gwadar with city ID: 1177446 was found
# Record 134,city name:Nagato with city ID: 1899102 was found
# Record 135,city name:Cuicatlan with city ID: 3518729 was found
# Record 136,city name:Sandnessjøen with city ID: 3140301 was found
# attawapiskat, was not found
# illoqqortoormiut, was not found
# Record 137,city name:Qaanaaq with city ID: 3831208 was found
# Record 138,city name:Ayr with city ID: 2656708 was found
# Record 139,city name:Puerto Asís with city ID: 3671549 was found
# Record 140,city name:Brazzaville with city ID: 2260535 was found
# Record 141,city name:Bowen with city ID: 2174444 was found
# Record 142,city name:Adolfo López Mateos with city ID: 3976161 was found
# Record 143,city name:Hithadhoo with city ID: 1282256 was found
# Record 144,city name:Fremont with city ID: 5350734 was found
# Record 145,city name:Ozernovskiy with city ID: 2122293 was found
# Record 146,city name:La Santisima Trinidad with city ID: 3902377 was found
# Record 147,city name:Kingsville with city ID: 4703384 was found
# Record 148,city name:High Rock with city ID: 3572189 was found
# Record 149,city name:Emerald with city ID: 2167426 was found
# Record 150,city name:Murdochville with city ID: 6943820 was found
# Record 151,city name:Iberia with city ID: 4328254 was found
# Record 152,city name:Paamiut with city ID: 3421193 was found
# malwan, was not found
# Record 153,city name:Aruvankad with city ID: 1278433 was found
# Record 154,city name:Talaya with city ID: 2120769 was found
# Record 155,city name:Lakes Entrance with city ID: 2160735 was found
# Record 156,city name:Matara with city ID: 1235846 was found
# Record 157,city name:George Town with city ID: 1735106 was found
# Record 158,city name:Tual with city ID: 1623197 was found
# Record 159,city name:Qui Nhon with city ID: 1568574 was found
# Record 160,city name:Auki with city ID: 2109701 was found
# Record 161,city name:Ilulissat with city ID: 3423146 was found
# Record 162,city name:Bambous Virieux with city ID: 1106677 was found
# Record 163,city name:Vardø with city ID: 777019 was found
# Record 164,city name:Örnsköldsvik with city ID: 2686469 was found
# Record 165,city name:San Cristobal with city ID: 3628473 was found
# Record 166,city name:Leiyang with city ID: 1804208 was found
# Record 167,city name:Lebu with city ID: 3883457 was found
# Record 168,city name:Buala with city ID: 2109528 was found
# Record 169,city name:Sfântu Gheorghe with city ID: 667303 was found
# Record 170,city name:Provideniya with city ID: 4031574 was found
# Record 171,city name:Shingū with city ID: 1847947 was found
# Record 172,city name:Portobelo with city ID: 3702577 was found
# Record 173,city name:Thompson with city ID: 6165406 was found
# Record 174,city name:Independência with city ID: 3398255 was found
# Record 175,city name:Kalmunai with city ID: 1242110 was found
# Record 176,city name:Faanui with city ID: 4034551 was found
# Record 177,city name:Cherskiy with city ID: 2126199 was found
# Record 178,city name:Chipinge with city ID: 893549 was found
# Record 179,city name:Keetmanshoop with city ID: 3356264 was found
# Record 180,city name:Cedral with city ID: 4014914 was found
# Record 181,city name:Viedma with city ID: 3832899 was found
# Record 182,city name:Siparia with city ID: 3573681 was found
# Record 183,city name:Sovetskiy with city ID: 1491230 was found
# Record 184,city name:Atar with city ID: 2381334 was found
# Record 185,city name:Nemuro with city ID: 2128975 was found
# Record 186,city name:Bethel with city ID: 5282297 was found
# saleaula, was not found
# Record 187,city name:Zaria with city ID: 2317765 was found
# Record 188,city name:Kanye with city ID: 933685 was found
# Record 189,city name:Nyimba with city ID: 900056 was found
# Record 190,city name:Aksay with city ID: 583673 was found
# Record 191,city name:Bada with city ID: 2027275 was found
# Record 192,city name:Charter Township of Clinton with city ID: 4989133 was found
# Record 193,city name:Avarua with city ID: 4035715 was found
# Record 194,city name:Nha Trang with city ID: 1572151 was found
# Record 195,city name:Río Gallegos with city ID: 3838859 was found
# Record 196,city name:Severo-Kuril'sk with city ID: 2121385 was found
# Record 197,city name:Kumul with city ID: 1529484 was found
# nizhneyansk, was not found
# Record 198,city name:Nanortalik with city ID: 3421765 was found
# Record 199,city name:Puerto Ayora with city ID: 3652764 was found
# Record 200,city name:Riyadh with city ID: 108410 was found
# Record 201,city name:Suntar with city ID: 2015913 was found
# Record 202,city name:Mwene-Ditu with city ID: 207570 was found
# Record 203,city name:Cabo San Lucas with city ID: 3985710 was found
# Record 204,city name:Airai with city ID: 1651810 was found
# Record 205,city name:Berdigestyakh with city ID: 2026861 was found
# Record 206,city name:Kamenka with city ID: 553766 was found
# Record 207,city name:Ābdānān with city ID: 145233 was found
# Record 208,city name:Mackenzie with city ID: 6063191 was found
# Record 209,city name:Palembang with city ID: 1633070 was found
# Record 210,city name:Oshkosh with city ID: 5265838 was found
# Record 211,city name:Vărşag with city ID: 663158 was found
# vaitupu, was not found
# Record 212,city name:Rehoboth with city ID: 3353540 was found
# Record 213,city name:Neuquén with city ID: 3843123 was found
# Record 214,city name:Castro with city ID: 3466704 was found
# Record 215,city name:Necochea with city ID: 3430443 was found
# Record 216,city name:Calatayud with city ID: 3127047 was found
# Record 217,city name:Hervey Bay with city ID: 2146219 was found
# Record 218,city name:San Luis with city ID: 3837056 was found
# Record 219,city name:Fairbanks with city ID: 5861897 was found
# Record 220,city name:Bubaque with city ID: 2374583 was found
# gorno-chuyskiy, was not found
# Record 221,city name:Phan Thiet with city ID: 1571058 was found
# Record 222,city name:Praia with city ID: 3374333 was found
# kazalinsk, was not found
# Record 223,city name:Karasjok with city ID: 779350 was found
# Record 224,city name:Sal Rei with city ID: 3374235 was found
# Record 225,city name:Ladário with city ID: 3459352 was found
# Record 226,city name:Isangel with city ID: 2136825 was found
# Record 227,city name:Quatre Cocos with city ID: 1106643 was found
# Record 228,city name:Oktyabr'skoye with city ID: 515805 was found
# Record 229,city name:Samarai with city ID: 2132606 was found
# Record 230,city name:Sayán with city ID: 3928867 was found
# Record 231,city name:Forsytheganj with city ID: 10722858 was found
# Record 232,city name:Vrangel' with city ID: 2013258 was found
# westpunt, was not found
# Record 233,city name:Tasiilaq with city ID: 3424607 was found
# Record 234,city name:Avera with city ID: 4231997 was found
# Record 235,city name:Chokurdakh with city ID: 2126123 was found
# Record 236,city name:Itarema with city ID: 3393692 was found
# Record 237,city name:Snyder with city ID: 5530921 was found
# umzimvubu, was not found
# Record 238,city name:Waingapu with city ID: 1622318 was found
# Record 239,city name:Lagunas with city ID: 3695844 was found
# Record 240,city name:Mezen' with city ID: 527321 was found
# Record 241,city name:Laguna with city ID: 5364271 was found
# Record 242,city name:Pringsewu with city ID: 1630639 was found
# Record 243,city name:Asău with city ID: 686090 was found
# amderma, was not found
# Record 244,city name:Envira with city ID: 3664301 was found
# Record 245,city name:Acaraú with city ID: 3408368 was found
# aflu, was not found
# Record 246,city name:São Caetano de Odivelas with city ID: 3388926 was found
# Record 247,city name:Kamień Pomorski with city ID: 3096765 was found
# Record 248,city name:Tevriz with city ID: 1489661 was found
# Record 249,city name:Kobelyaky with city ID: 705544 was found
# Record 250,city name:Wangaratta with city ID: 2144764 was found
# Record 251,city name:Drayton Valley with city ID: 5942547 was found
# Record 252,city name:Bandarbeyla with city ID: 64814 was found
# khonuu, was not found
# Record 253,city name:Chandrakona with city ID: 1274699 was found
# lolua, was not found
# Record 254,city name:São João da Barra with city ID: 3448903 was found
# Record 255,city name:Half Moon Bay with city ID: 5354943 was found
# Record 256,city name:Nevel'sk with city ID: 2122894 was found
# Record 257,city name:Kaeo with city ID: 2189343 was found
# Record 258,city name:Port Elizabeth with city ID: 964420 was found
# barentsburg, was not found
# Record 259,city name:Dalbandin with city ID: 1180729 was found
# Record 260,city name:Bathsheba with city ID: 3374083 was found
# Record 261,city name:Sarangani with city ID: 1687186 was found
# Record 262,city name:Alofi with city ID: 4036284 was found
# Record 263,city name:Qaqortoq with city ID: 3420846 was found
# Record 264,city name:Nizwá with city ID: 286987 was found
# Record 265,city name:Vostok with city ID: 2013279 was found
# Record 266,city name:Gravdal with city ID: 3155152 was found
# Record 267,city name:Paka with city ID: 1734313 was found
# Record 268,city name:Torbay with city ID: 6167817 was found
# Record 269,city name:Petra with city ID: 246008 was found
# Record 270,city name:Karlskrona with city ID: 2701713 was found
# Record 271,city name:Hamilton with city ID: 4513583 was found
# Record 272,city name:Portland with city ID: 5746545 was found
# Record 273,city name:Oranjestad with city ID: 3577154 was found
# Record 274,city name:Talnakh with city ID: 1490256 was found
# Record 275,city name:São Filipe with city ID: 3374210 was found
# Record 276,city name:Nishihara with city ID: 1855342 was found
# Record 277,city name:Rock Sound with city ID: 3571592 was found
# Record 278,city name:Ahipara with city ID: 2194098 was found
# Record 279,city name:Sur with city ID: 286245 was found
# Record 280,city name:Obihiro with city ID: 2128815 was found
# mys shmidta, was not found
# Record 281,city name:Mildura with city ID: 2157698 was found
# Record 282,city name:Mezhdurechensk with city ID: 1498920 was found
# Record 283,city name:Taoudenni with city ID: 2450173 was found
# Record 284,city name:Tessalit with city ID: 2449893 was found
# Record 285,city name:Muskegon with city ID: 5003136 was found
# Record 286,city name:Lieksa with city ID: 648090 was found
# ngukurr, was not found
# Record 287,city name:Cornwall with city ID: 5928065 was found
# Record 288,city name:Norden with city ID: 2862118 was found
# Record 289,city name:Kiryat Gat with city ID: 293842 was found
# Record 290,city name:Kavieng with city ID: 2094342 was found
# Record 291,city name:Turinsk with city ID: 1488933 was found
# Record 292,city name:Mahébourg with city ID: 934322 was found
# Record 293,city name:Kawalu with city ID: 1640902 was found
# Record 294,city name:Walvis Bay with city ID: 3359638 was found
# malakisi, was not found
# Record 295,city name:La Asuncion with city ID: 3480908 was found
# Record 296,city name:Inhapim with city ID: 3461214 was found
# Record 297,city name:Cockburn Town with city ID: 3576994 was found
# Record 298,city name:San Patricio with city ID: 3985168 was found
# Record 299,city name:Siuna with city ID: 3616253 was found
# Record 300,city name:Mbalmayo with city ID: 2228079 was found
# Record 301,city name:Greencastle with city ID: 4258273 was found
# Record 302,city name:Beni with city ID: 219057 was found
# Record 303,city name:Nagapattinam with city ID: 1262260 was found
# Record 304,city name:Ejea de los Caballeros with city ID: 3123688 was found
# Record 305,city name:Antofagasta with city ID: 3899539 was found
# Record 306,city name:Westerland with city ID: 2810284 was found
# sinkat, was not found
# Record 307,city name:Yumen with city ID: 1528998 was found
# Record 308,city name:Merauke with city ID: 2082539 was found
# tuggurt, was not found
# Record 309,city name:Hambantota with city ID: 1244926 was found
# karaul, was not found
# Record 310,city name:Deer Lake with city ID: 5937252 was found
# Record 311,city name:Goderich with city ID: 5962442 was found
# Record 312,city name:Pacific Grove with city ID: 5380437 was found
# Record 313,city name:Santa Isabel Rio Negro with city ID: 3662489 was found
# Record 314,city name:Vao with city ID: 2137773 was found
# Record 315,city name:Yabēlo with city ID: 326036 was found
# Record 316,city name:Vanderhoof with city ID: 6173361 was found
# Record 317,city name:Kruisfontein with city ID: 986717 was found
# Record 318,city name:Qasigiannguit with city ID: 3420768 was found
# Record 319,city name:Klaksvík with city ID: 2618795 was found
# Record 320,city name:Mayumba with city ID: 2399001 was found
# Record 321,city name:Gimbi with city ID: 336496 was found
# ferai, was not found
# Record 322,city name:Vila Franca do Campo with city ID: 3372472 was found
# Record 323,city name:Krivodol with city ID: 729909 was found
# Record 324,city name:Yeppoon with city ID: 2142316 was found
# Record 325,city name:Somerset East with city ID: 954161 was found
# Record 326,city name:Khilok with city ID: 2022463 was found
# Record 327,city name:Cayenne with city ID: 3382160 was found
# Record 328,city name:Rognan with city ID: 3141548 was found
# Record 329,city name:Aksha with city ID: 2028028 was found
# Record 330,city name:Kerman with city ID: 128234 was found
# Record 331,city name:Huarmey with city ID: 3939168 was found
# Record 332,city name:Camocim with city ID: 3403687 was found
# khomeynishahr, was not found
# Record 333,city name:Kankaanpää with city ID: 654363 was found
# Record 334,city name:Sobolevo with city ID: 525426 was found
# Record 335,city name:Khromtau with city ID: 609404 was found
# doctor pedro p. pena, was not found
# Record 336,city name:Korla with city ID: 1529376 was found
# Record 337,city name:Beloha with city ID: 1067565 was found
# Record 338,city name:Shache with city ID: 1280037 was found
# Record 339,city name:Ponta do Sol with city ID: 2264557 was found
# Record 340,city name:Rawson with city ID: 3839307 was found
# Record 341,city name:Kloulklubed with city ID: 7671223 was found
# Record 342,city name:Kysyl-Syr with city ID: 2021017 was found
# Record 343,city name:Salihorsk with city ID: 622428 was found
# Record 344,city name:Obo with city ID: 236950 was found
# Record 345,city name:Vila Velha with city ID: 3445026 was found
# Record 346,city name:Trelew with city ID: 3833883 was found
# Record 347,city name:Manokwari with city ID: 1636308 was found
# Record 348,city name:Pandan with city ID: 1695546 was found
# Record 349,city name:Nyurba with city ID: 2018735 was found
# Record 350,city name:Lavrentiya with city ID: 4031637 was found
# Record 351,city name:Arsikere with city ID: 1278354 was found
# Record 352,city name:Naze with city ID: 1855540 was found
# Record 353,city name:Along with city ID: 1278969 was found
# Record 354,city name:Bara with city ID: 2347758 was found
# Record 355,city name:Eidfjord with city ID: 3158668 was found
# Record 356,city name:Tigil' with city ID: 2120612 was found
# Record 357,city name:Kampot with city ID: 1831112 was found
# Record 358,city name:Karratha with city ID: 6620339 was found
# wulanhaote, was not found
# alotau, was not found
# Record 359,city name:Ørnes with city ID: 3143368 was found
# Record 360,city name:Marignane with city ID: 2995750 was found
# Record 361,city name:Visnes with city ID: 3131500 was found
# Record 362,city name:Vilhena with city ID: 3924679 was found
# Record 363,city name:Lenger with city ID: 1521379 was found
# Record 364,city name:Asunción with city ID: 3439389 was found
# Record 365,city name:Katherine with city ID: 2068655 was found
# Record 366,city name:Mitú with city ID: 3674676 was found
# Record 367,city name:San Juan Bautista with city ID: 3929493 was found
# Record 368,city name:Coyhaique with city ID: 3894426 was found
# Record 369,city name:Mossamedes with city ID: 3347019 was found
# Record 370,city name:Kirakira with city ID: 2178753 was found
# Record 371,city name:Verkhoyansk with city ID: 2013465 was found
# Record 372,city name:Griffith with city ID: 4920986 was found
# Record 373,city name:Levanger with city ID: 3147698 was found
# Record 374,city name:Mama with city ID: 2020313 was found
# Record 375,city name:Evensk with city ID: 2125693 was found
# Record 376,city name:Horsham with city ID: 2646557 was found
# Record 377,city name:Sabzawār with city ID: 118063 was found
# Record 378,city name:Sinnamary with city ID: 3380290 was found
# Record 379,city name:Andros with city ID: 265040 was found
# Record 380,city name:Sweetwater with city ID: 4174600 was found
# Record 381,city name:Cururupu with city ID: 3401148 was found
# Record 382,city name:Saldanha with city ID: 3361934 was found
# Record 383,city name:Khasan with city ID: 2039557 was found
# Record 384,city name:Harper with city ID: 2276492 was found
# Record 385,city name:Moose Factory with city ID: 6078372 was found
# Record 386,city name:Tula with city ID: 480562 was found
# Record 387,city name:Lufilufi with city ID: 4035249 was found
# Record 388,city name:Kungurtug with city ID: 1501377 was found
# Record 389,city name:Banda Aceh with city ID: 1215502 was found
# Record 390,city name:Loreto with city ID: 3998291 was found
# Record 391,city name:Kuah with city ID: 1222396 was found
# Record 392,city name:Barkly West with city ID: 1021040 was found
# Record 393,city name:Padang with city ID: 1633419 was found
# Record 394,city name:Dzilam González with city ID: 3529654 was found
# Record 395,city name:Camargo with city ID: 4013724 was found
# Record 396,city name:La Joya with city ID: 3525570 was found
# Record 397,city name:Palmer with city ID: 4946620 was found
# Record 398,city name:Nikolskoye with city ID: 546105 was found
# Record 399,city name:Constitución with city ID: 3893726 was found
# Record 400,city name:Tura with city ID: 1254046 was found
# Record 401,city name:Srednekolymsk with city ID: 2121025 was found
# Record 402,city name:Mogadishu with city ID: 53654 was found
# Record 403,city name:Nevinnomyssk with city ID: 522377 was found
# Record 404,city name:Kahului with city ID: 5847411 was found
# Record 405,city name:Oranjemund with city ID: 3354071 was found
# Record 406,city name:Iracoubo with city ID: 3381428 was found
# Record 407,city name:Makakilo City with city ID: 5850554 was found
# Record 408,city name:Aquiraz with city ID: 3407407 was found
# Record 409,city name:Progreso with city ID: 3521108 was found
# Record 410,city name:Koryazhma with city ID: 544370 was found
# barawe, was not found
# Record 411,city name:Ylivieska with city ID: 630768 was found
# Record 412,city name:Staraya Toropa with city ID: 489043 was found
# Record 413,city name:Bambanglipuro with city ID: 1650434 was found
# Record 414,city name:Abu Dhabi with city ID: 292968 was found
# Record 415,city name:Nanyang with city ID: 1799629 was found
# Record 416,city name:Clyde River with city ID: 5924351 was found
# Record 417,city name:Görele with city ID: 746565 was found
# Record 418,city name:Havøysund with city ID: 779622 was found
# Record 419,city name:Kieta with city ID: 2094027 was found
# Record 420,city name:Puerto Escondido with city ID: 3520994 was found
# Record 421,city name:Wencheng with city ID: 1791539 was found
# Record 422,city name:Verāval with city ID: 1253237 was found
# Record 423,city name:La Ronge with city ID: 6050066 was found
# Record 424,city name:Basco with city ID: 1726449 was found
# Record 425,city name:Coquimbo with city ID: 3893629 was found
# Record 426,city name:Woodward with city ID: 4556050 was found
# Record 427,city name:Mackay with city ID: 2159220 was found
# Record 428,city name:Hongjiang with city ID: 1808106 was found
# Record 429,city name:Sitka with city ID: 5557293 was found
# Record 430,city name:Hurricane with city ID: 5540831 was found
# Record 431,city name:Koslan with city ID: 544084 was found
# Record 432,city name:Twentynine Palms with city ID: 5404198 was found
# grand river south east, was not found
# Record 433,city name:Novoagansk with city ID: 1497210 was found
# Record 434,city name:Port Hedland with city ID: 2063042 was found
# Record 435,city name:Victor Harbor with city ID: 2059470 was found
# Record 436,city name:Amazar with city ID: 2027806 was found
# tarudant, was not found
# Record 437,city name:Acurenam with city ID: 2310533 was found
# Record 438,city name:Rocha with city ID: 3440777 was found
# Record 439,city name:Dandong with city ID: 2037886 was found
# Record 440,city name:Timbiquí with city ID: 3667070 was found
# Record 441,city name:Brookhaven with city ID: 4419500 was found
# Record 442,city name:Flin Flon with city ID: 5954718 was found
# Record 443,city name:Surin with city ID: 1606030 was found
# Record 444,city name:Salalah with city ID: 286621 was found
# Record 445,city name:Chadan with city ID: 1508501 was found
# Record 446,city name:Inhambane with city ID: 1045114 was found
# Record 447,city name:Ketchikan with city ID: 5554428 was found
# Record 448,city name:Kutum with city ID: 371745 was found
# Record 449,city name:Labuhan with city ID: 8079926 was found
# Record 450,city name:Circleville with city ID: 4508778 was found
# Record 451,city name:Dunmore Town with city ID: 3572462 was found
# Record 452,city name:Ratnagiri with city ID: 1258338 was found
# Record 453,city name:Manono with city ID: 209598 was found
# jabiru, was not found
# Record 454,city name:Troitskoye with city ID: 1489209 was found
# Record 455,city name:Basoko with city ID: 219414 was found
# Record 456,city name:Brežice with city ID: 3203412 was found
# Record 457,city name:Quelimane with city ID: 1028434 was found
# Record 458,city name:Hope with city ID: 4115181 was found
# Record 459,city name:Marshfield with city ID: 5261969 was found
# Record 460,city name:Pierre with city ID: 5767918 was found
# Record 461,city name:Vitim with city ID: 2013375 was found
# Record 462,city name:Yar-Sale with city ID: 1486321 was found
# Record 463,city name:Chapais with city ID: 5919850 was found
# Record 464,city name:Port Blair with city ID: 1259385 was found
# Record 465,city name:Zhoucheng with city ID: 1920772 was found
# Record 466,city name:Maniitsoq with city ID: 3421982 was found
# Record 467,city name:Ugoofaaru with city ID: 1337619 was found
# tumannyy, was not found
# Record 468,city name:Russell with city ID: 4047434 was found
# Record 469,city name:Dafeng with city ID: 1814435 was found
# Record 470,city name:Margate with city ID: 2643044 was found
# Record 471,city name:Palana with city ID: 2122262 was found
# Record 472,city name:Tomatlán with city ID: 3981391 was found
# Record 473,city name:San Jose with city ID: 5392171 was found
# Record 474,city name:Abashiri with city ID: 2130741 was found
# Record 475,city name:Sydney with city ID: 2147714 was found
# skagastrond, was not found
# Record 476,city name:Māndal with city ID: 1263917 was found
# Record 477,city name:Kanakeravan with city ID: 616052 was found
# Record 478,city name:Worland with city ID: 5843495 was found
# Record 479,city name:Broome with city ID: 5110365 was found
# Record 480,city name:North Bend with city ID: 5742974 was found
# vestbygda, was not found
# Record 481,city name:Santa Cruz de la Sierra with city ID: 3904906 was found
# Record 482,city name:Bolaños de Calatrava with city ID: 2520875 was found
# obluche, was not found
# Record 483,city name:Santa with city ID: 1688420 was found
# Record 484,city name:Omboué with city ID: 2396853 was found
# Record 485,city name:Tomohon with city ID: 1623446 was found
# Record 486,city name:Adrar with city ID: 2381972 was found
# Record 487,city name:Estelle with city ID: 4323873 was found
# paucartambo, was not found
# Record 488,city name:Talakan with city ID: 2015686 was found
# dibaya, was not found
# yanan, was not found
# Record 489,city name:Sherbrooke with city ID: 6146143 was found
# Record 490,city name:Kenai with city ID: 5866063 was found
# Record 491,city name:Nālūt with city ID: 2214432 was found
# Record 492,city name:Centralia with city ID: 5789683 was found
# Record 493,city name:Le François with city ID: 3570429 was found
# Record 494,city name:Dunedin with city ID: 2191562 was found
# Record 495,city name:Oyem with city ID: 2396646 was found
# Record 496,city name:Caravelas with city ID: 3466980 was found
# Record 497,city name:Assaí with city ID: 3471377 was found
# Record 498,city name:Grindavik with city ID: 3416888 was found
# Record 499,city name:Jishou with city ID: 1805270 was found
# Record 500,city name:Tiznit Province with city ID: 2527087 was found
# marcona, was not found
# Record 501,city name:Verkhnyaya Toyma with city ID: 474470 was found
# Record 502,city name:Butka with city ID: 1508589 was found
# Record 503,city name:Sidi Ali with city ID: 2487130 was found
# Record 504,city name:Dargaville with city ID: 2191911 was found
# Record 505,city name:Mukhen with city ID: 2019718 was found
# Record 506,city name:Porto-Novo with city ID: 2392087 was found
# Record 507,city name:Baoqing with city ID: 2038446 was found
# Record 508,city name:Rockingham with city ID: 5091860 was found
# Record 509,city name:Hare Bay with city ID: 5970873 was found
# warqla, was not found
# Record 510,city name:Jaumave with city ID: 3526564 was found
# Record 511,city name:Fengzhen with city ID: 2037391 was found
# Record 512,city name:Seymchan with city ID: 2121373 was found
# Record 513,city name:Kuytun with city ID: 2021093 was found
# Record 514,city name:Forio with city ID: 3176748 was found
# Record 515,city name:Souillac with city ID: 933995 was found
# Record 516,city name:Kholtoson with city ID: 2022369 was found
# Record 517,city name:Kingston with city ID: 3489854 was found
# Record 518,city name:São José da Coroa Grande with city ID: 3388456 was found
# Record 519,city name:Moses Lake with city ID: 5803990 was found
# Record 520,city name:Winnemucca with city ID: 5710360 was found
# Record 521,city name:Cramlington with city ID: 2652095 was found
# tabiauea, was not found
# Record 522,city name:Geraldton with city ID: 2070998 was found
# Record 523,city name:Camacha with city ID: 2270385 was found
# Record 524,city name:Ust'-Barguzin with city ID: 2013986 was found
# Record 525,city name:Diapaga with city ID: 2361373 was found
# Record 526,city name:Namwala with city ID: 901766 was found
# Record 527,city name:Akdepe with city ID: 601551 was found
# Record 528,city name:Beira with city ID: 1052373 was found
# Record 529,city name:Nieuwpoort with city ID: 2790153 was found
# Record 530,city name:Lenine with city ID: 703261 was found
# Record 531,city name:Ann Arbor with city ID: 4984247 was found
# Record 532,city name:Severnoye with city ID: 1492607 was found
# Record 533,city name:Mbini with city ID: 2308278 was found
# Record 534,city name:Kodinsk with city ID: 1503037 was found
# Record 535,city name:Harindānga with city ID: 1349090 was found
# Record 536,city name:Katiola with city ID: 2287298 was found
# Record 537,city name:Burns Lake with city ID: 5911745 was found
# Record 538,city name:Huambo with city ID: 3348313 was found
# Record 539,city name:Kapuskasing with city ID: 5989403 was found
# Record 540,city name:Píllaro with city ID: 3653159 was found
# Record 541,city name:Pyaozerskiy with city ID: 503581 was found
# Record 542,city name:Kurkino with city ID: 538733 was found
# Record 543,city name:São Miguel do Tapuio with city ID: 3388266 was found
# Record 544,city name:La Spezia with city ID: 3175081 was found
# Record 545,city name:Dingle with city ID: 1714733 was found
# Record 546,city name:Matamoros with city ID: 3996426 was found
# Record 547,city name:Vadsø with city ID: 777073 was found
# Record 548,city name:Lüderitz with city ID: 3355672 was found
# Record 549,city name:Saint-Pierre with city ID: 935214 was found
# Record 550,city name:Dauphin with city ID: 5935341 was found
# tsihombe, was not found
# Record 551,city name:Mahajanga with city ID: 1062663 was found
# Record 552,city name:Youghal with city ID: 2960869 was found
# Record 553,city name:Maun with city ID: 933366 was found
# Record 554,city name:Tandil with city ID: 3427833 was found
# Record 555,city name:Morgan City with city ID: 4333811 was found
# Record 556,city name:Bulgan with city ID: 2032201 was found
# Record 557,city name:Erenhot with city ID: 2037485 was found
# Record 558,city name:Husavik with city ID: 2629833 was found
# Record 559,city name:Zyryanka with city ID: 2119283 was found
# Record 560,city name:Narón with city ID: 3115739 was found
# Record 561,city name:Kyren with city ID: 2021031 was found
# Record 562,city name:Banjar with city ID: 1650232 was found

# %%
#Create a DataFrame to hold the weather information
weather_data_df=pd.DataFrame({"City ID":city_id, 
                              "City Name":city_name, 
                              "Country Code":country,
                              "Date": date,
                              "Latitude":latitude,
                              "Longitude":longitude, 
                              "Humidity %":humidity, 
                              "Temperature (F)":temperature,
                              "Wind Speed (mph)":wind_speed, 
                              "Cloudiness %":cloudiness})

weather_data_df
# Out:
#      City ID  City Name Country Code      Date  Latitude  Longitude  \
# 0     780687   Berlevåg           NO  05/05/20     70.86      29.09
# 1    2075265  Busselton           AU  05/05/20    -33.65     115.33
# 2    2640377   Penzance           GB  05/05/20     50.12      -5.54
# 3    4030556    Rikitea           PF  05/05/20    -23.12    -134.97
# 4    1819729  Hong Kong           HK  05/05/20     22.29     114.16
# ..       ...        ...          ...       ...       ...        ...
# 557  2629833    Husavik           IS  05/05/20     66.04     -17.34
# 558  2119283   Zyryanka           RU  05/05/20     65.75     150.85
# 559  3115739      Narón           ES  05/05/20     43.52      -8.15
# 560  2021031      Kyren           RU  05/05/20     51.68     102.14
# 561  1650232     Banjar           ID  05/05/20     -8.19     114.97
#
#      Humidity %  Temperature (F)  Wind Speed (mph)  Cloudiness %
# 0            59           276.15             10.30           100
# 1            98           282.36             13.12            99
# 2           100           283.71              8.70            98
# 3            62           296.24              4.48           100
# 4            78           300.57              2.68           100
# ..          ...              ...               ...           ...
# 557          34           285.15             14.90             0
# 558          98           270.17              2.03            83
# 559          68           289.51              5.70           100
# 560          82           277.46              1.80           100
# 561          94           301.15              3.10            40
#
# [562 rows x 10 columns]

# %%
#Create a file with all the weather information (csv)
weather_data_df.to_csv("weather_data.csv",encoding="utf-8", index=False)

# %% [markdown]
# ## Scatter Plots

# %%
# Create a scatter plot for temperature & latitude
x_values = weather_data_df["Latitude"]
y_values = weather_data_df["Temperature (F)"]
plt.scatter(x_values,y_values)
plt.title(f"City Latitude & Temperature (F)")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")

plt.savefig("latitude_vs_temperature.png")
plt.show()

# %% [markdown]
# Observations:
#
# The City Latitude & Temperature scatter plot makes a good representation of the earth's weather in general. Cities with higher tempetures cluster around the equator, between 0 and 20 degrees, and the tempeture drops as cities get closer to the earth's north and south poles around -40 and around 60 degrees.

# %%
# Create a scatter plot for humidity (%) & Latitude
x_values = weather_data_df["Latitude"]
y_values = weather_data_df["Humidity %"]
plt.scatter(x_values,y_values)
plt.title(f" City Latitude & Humidity % ")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")

plt.savefig("humidity_vs_latitude.png")
plt.show()

# %% [markdown]
# Observations:
#
# There is no appearent correlation between humidity and latitude in the City Latitude & Humidity scatter plot. However, we can see that many cities have humidity higher than 60%.It would be interesting to see the humidity percentage in the summer vs the winter.

# %%
# Create a scatter plot for cloudiness (%) & latitude
x_values = weather_data_df["Latitude"]
y_values = weather_data_df["Cloudiness %"]
plt.scatter(x_values,y_values)
plt.title(f" City Latitude & Cloudiness %")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")

plt.savefig("cloudiness_vs_latitude.png")
plt.show()

# %% [markdown]
# Observations:
#
# There is no appearent correlation between cloudiness and latitude in the City Latitude & Cloudiness scatter plot. However, we can see some linear cloudiness clusters at 0%, 40%, 75%, and 100% across all latitudes.

# %%
# Create a scatter plot for wind speed (mph) & latitude
x_values = weather_data_df["Latitude"]
y_values = weather_data_df["Wind Speed (mph)"]
plt.scatter(x_values,y_values)
plt.title(f" City Latitude & Wind Speed (mph)")
plt.xlabel("Latitude")
plt.ylabel(" Wind Speed (mph)")

plt.savefig("wind_speed_vs_latitude.png")
plt.show()

# %% [markdown]
# Observations:
#
# There is no appearent correlation between wind speed and latitude in the City Latitude & Wind Speed scatter plot, however it appears for most cities the wind speed is less than 15 mph. There are also a wind speed outliers in the northern hemisphere.

# %% [markdown]
# ## Northern and Southern Hemisphere Plots

# %%
#Set two seperate list with northern hemisphere and southern hemisphere data
north_hem=weather_data_df.loc[weather_data_df["Latitude"] >= 0,:]
south_hem=weather_data_df.loc[weather_data_df["Latitude"] < 0,:]

south_hem.head()
# Out:
#     City ID      City Name Country Code      Date  Latitude  Longitude  \
# 1   2075265      Busselton           AU  05/05/20    -33.65     115.33
# 3   4030556        Rikitea           PF  05/05/20    -23.12    -134.97
# 7   3443061           Chui           UY  05/05/20    -33.70     -53.46
# 12  3466165       Cidreira           BR  05/05/20    -30.18     -50.21
# 13  2156643  Mount Gambier           AU  05/05/20    -37.83     140.77
#
#     Humidity %  Temperature (F)  Wind Speed (mph)  Cloudiness %
# 1           98           282.36             13.12            99
# 3           62           296.24              4.48           100
# 7           61           289.16              7.66            13
# 12          86           293.14              3.44            92
# 13          76           283.15              3.60           100

# %%
#Plot regression line on scatter plots
def plot_regression(x_values,y_values,x_axis_label,y_axis_label, hemisphere):
    (slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    regress_values = x_values * slope + intercept
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.title(f" {hemisphere}-City {x_axis_label} & {y_axis_label}")
    plt.xlabel(x_axis_label)
    plt.ylabel(y_axis_label)
    print(f"The r-squared is: {rvalue}")
    print(line_eq)
    plt.show()

# %%
#plot regression line for northern hemisphere and temperature
plot_regression(north_hem["Latitude"],north_hem["Temperature (F)"],"Latitude","Temperature (F)", "Northern Hemisphere")

plt.savefig('north_temp.png')
# Out:
# The r-squared is: -0.8589038002560613
# y = -0.52x + 308.82

# %%
#plot regression line for southern hemisphere and temperature
plot_regression(south_hem["Latitude"],south_hem["Temperature (F)"],"Latitude","Temperature (F)", "Southern Hemisphere")

plt.savefig('south_temp.png')
# Out:
# The r-squared is: 0.8055231934690757
# y = 0.41x + 302.1

# %%
#plot regression line for northern hemisphere and humidity
plot_regression(north_hem["Latitude"],north_hem["Humidity %"],"Latitude","Humidity %", "Northern Hemisphere")

plt.savefig('north_humidity.png')
# Out:
# The r-squared is: 0.1683911637017058
# y = 0.21x + 58.43

# %%
#plot regression line for southern hemisphere and humidity
plot_regression(south_hem["Latitude"],south_hem["Humidity %"],"Latitude","Humidity %", "Southern Hemisphere")

plt.savefig('south_humidity.png')
# Out:
# The r-squared is: 0.22408140096709736
# y = 0.29x + 79.21

# %%
#plot regression line for northern hemisphere and cloudiness
plot_regression(north_hem["Latitude"],north_hem["Cloudiness %"],"Latitude","Cloudiness %", "Northern Hemisphere")

plt.savefig('north_cloudiness.png')
# Out:
# The r-squared is: 0.1726710382788126
# y = 0.35x + 38.4

# %%
#plot regression line for southern hemisphere and cloudiness
plot_regression(south_hem["Latitude"],south_hem["Cloudiness %"],"Latitude","Cloudiness %", "Southern Hemisphere")

plt.savefig('south_cloudiness.png')
# Out:
# The r-squared is: 0.06654669479273506
# y = 0.19x + 54.09

# %%
#plot pregression line for northern hemisphere and wind speed
plot_regression(north_hem["Latitude"],north_hem["Wind Speed (mph)"],"Latitude","Wind Speed (mph)", "Northern Hemisphere")

plt.savefig('north_windspeed.png')
# Out:
# The r-squared is: 0.10546898959179575
# y = 0.01x + 3.26

# %%
#plot regression line for southern hemisphere and wind speed
plot_regression(south_hem["Latitude"],south_hem["Wind Speed (mph)"],"Latitude","Wind Speed (mph)", "Southern Hemisphere")

plt.savefig('south_windspeed.png')
# Out:
# The r-squared is: -0.22486558835578602
# y = -0.04x + 2.84
